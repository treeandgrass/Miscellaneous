# %%
from keras.models import Model
from keras.layers import Dense, Input, BatchNormalization, Activation, Conv2D, MaxPooling2D, AveragePooling2D, Dropout
from keras.layers import Add, Reshape, Flatten
from keras import backend as K
from keras.utils import plot_model
from keras.utils.vis_utils import model_to_dot
from IPython.display import display
import numpy as np
import matplotlib.pyplot as plt
from ImageUtils import ImageUtils
import pickle
from keras import regularizers
# Out:
# D:\sf\conda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#基本常量
sourceFolder = 'D:/jupyter/car-management/recognitionalgorithm/dataset/rimages'
targetFolder = 'D:/jupyter/car-management/recognitionalgorithm/dataset/rimagesResize320'
root = 'D:/jupyter/car-management/recognitionalgorithm/dataset'
Xfilename = 'licenseplateL.npy'
Yfilename = 'label.npy'
filename = '字典.xlsx'

# %%
#加载图片数据
utils = ImageUtils()

# %%
#检查图片数据
X_train, Y_train = utils.load(root, Xfilename, Yfilename)
print(X_train.shape)
print(Y_train.shape)
print(utils.getLabel(root, filename, Y_train[10]))
plt.imshow(X_train[10])
# Out:
# (1222, 320, 320)
# (1222, 7)
# 云D86999

# %%
def identify_block(X, filters, name, strides):
    conv_name = 'identify_conv' + str(name)
    bn_name = 'identify_bn_name' + str(name)
    activation_name = 'identify_activation_name' + str(name)
    add_name = 'identify_add' + str(name)
    skip_name = 'identify_skip' + str(name)
    
    f_1_1, f_1_2, skip_1_1 = filters
    
    '''first unit'''
    conv_1_1 = Conv2D(f_1_1, (3, 3), strides = strides, padding = 'same', name = conv_name + '_1_1', kernel_initializer = 'truncated_normal', kernel_regularizer = regularizers.l2(0.001))(X)
    bn_1_1 = BatchNormalization(name = bn_name + '_1_1')(conv_1_1)
    activation_1_1 = Activation('relu', name = activation_name + '_1_1')(bn_1_1)
    
    '''second unit'''
    conv_2_1 = Conv2D(f_1_2, (3, 3), strides = strides, padding = 'same', name = conv_name + '_2_1', kernel_initializer = 'truncated_normal', kernel_regularizer = regularizers.l2(0.001))(activation_1_1)
    bn_2_1 = BatchNormalization(name = bn_name + '_2_1')(conv_2_1)
    activation_2_1 = Activation('relu', name = activation_name + '_2_1')(bn_2_1)
    
    '''skip unit'''
    skip_strides = 2 * strides
    if strides == 1:
        skip_strides = 1
        
    conv_skip_1_1 = Conv2D(skip_1_1, (3, 3), strides = skip_strides, padding = 'same', name = skip_name + '_1_1', kernel_initializer = 'truncated_normal', kernel_regularizer = regularizers.l2(0.001))(X)
    
    identify = Add(name = add_name + '_1_1')([activation_2_1, conv_skip_1_1])
    
    return identify

# %%
'''build convlution block'''
def bottleneck_block(X, filters, name, strides):
    conv_name = 'bk_conv' + str(name)
    bn_name = 'bk_bn' + str(name)
    activation_name = 'bk_an' + str(name)
    add_name = 'bk_add' + str(name)
    skip_name = 'bk_sk' + str(name)
    
    f_1_1, f_1_2, f_1_3, skip_1_1 = filters
    
    '''first unit'''
    conv_1_1 = Conv2D(f_1_1, (1, 1), strides = strides, padding = 'same', name = conv_name + '1_1', kernel_initializer = 'truncated_normal', kernel_regularizer = regularizers.l2(0.001))(X)
    bn_1_1 = BatchNormalization(name = bn_name + '1_1')(conv_1_1)
    activation_1_1 = Activation('relu', name = activation_name + '1_1')(bn_1_1)
    
    '''second unit'''
    conv_2_1 = Conv2D(f_1_2, (3, 3), strides = strides, padding = 'same', name = conv_name + '2_1', kernel_initializer = 'truncated_normal', kernel_regularizer = regularizers.l2(0.001))(activation_1_1)
    bn_2_1 = BatchNormalization(name = bn_name + '2_1')(conv_2_1)
    activation_2_1 = Activation('relu', name = activation_name + '2_1')(bn_2_1)
    
    '''skip unit'''
    conv_3_1 = Conv2D(f_1_3, (1, 1), strides = strides, padding = 'same', name = conv_name + '3_1', kernel_initializer = 'truncated_normal', kernel_regularizer = regularizers.l2(0.001))(activation_2_1)
    bn_3_1 = BatchNormalization(name = bn_name + '3_1')(conv_3_1)
    activation_3_1 = Activation('relu', name = activation_name + '3_1')(bn_3_1)
    
    '''skip unit'''
    skip_strides = int(pow(strides, 3))
    if strides == 1:
        skip_strides = 1
    conv_skip_1_1 = Conv2D(skip_1_1, (3, 3), strides = skip_strides, name = skip_name + 'c_1_1', padding = 'same', kernel_initializer = 'truncated_normal', kernel_regularizer = regularizers.l2(0.001))(X)
    bn_skip_1_1 = BatchNormalization(name = skip_name + '_1_1')(conv_skip_1_1)
    activation_skip_1_1 = Activation('relu', name = skip_name + 'an_1_1')(bn_skip_1_1)
    
    
    bottleneck = Add(name = add_name + '_1_1')([activation_3_1, activation_skip_1_1])
    
    return bottleneck

# %%
'''build full network'''
def resnet(input_shape, full_conncet_nums = (512, 7)):
    '''inputs'''
    inputs = Input(shape = input_shape)
    
    
    '''128 filters, identify name: 1  256 filters, bottleneck name: 1'''
    bottleneck_block_1 = bottleneck_block(inputs, filters = (128, 128, 128, 128), name = 1, strides = 2)
    identify_block_1 = identify_block(bottleneck_block_1, filters = (256, 256, 256), name = 1, strides = 1)
    
    
    '''max pooling'''
    mp2d = MaxPooling2D(pool_size = (2, 2))(identify_block_1)
    
    '''relu activation'''
    an_block_1 = Activation('relu', name = 'model_an_1')(mp2d)
    
    '''dropout'''
    d_bottleneck_block_1 = Dropout(0.25)(an_block_1)
    
    '''256 filters, identify name: 2  512 filters, bottleneck name: 2'''
    bottleneck_block_2 = bottleneck_block(d_bottleneck_block_1, filters = (512, 512, 512, 512), name = 2, strides = 1)
    identify_block_2 = identify_block(bottleneck_block_2, filters = (1024, 1024, 1024), name = 2, strides = 1)
    
    '''relu activation'''
    an_block_2 = Activation('relu', name = 'model_an_2')(identify_block_2)
    
    '''dropout'''
    d_bottleneck_block_2 = Dropout(0.25)(an_block_2)
    
    '''1024 filters, identify name: 2  2048 filters, bottleneck name: 2'''
#     bottleneck_block_3 = bottleneck_block(d_bottleneck_block_2, filters = (1024, 1024, 1024, 1024), name = 3, strides = 2)
#     identify_block_3 = identify_block(d_bottleneck_block_2, filters = (2048, 2048, 2048), name = 3, strides = 2)
    
    '''average pooling'''
    ap2d = AveragePooling2D(pool_size = (1, 1))(d_bottleneck_block_2)
    
    '''dropout 0.05'''
    d_bottleneck_block_3 = Dropout(0.5)(ap2d)
    
    
    '''flatten'''
    flatten = Flatten()(d_bottleneck_block_3)
    
    '''full connect params'''
    full_connect_num_1, full_connect_num_2 = full_conncet_nums
    
    '''full connect layer 1'''
    full_connect1 = Dense(full_connect_num_1, activation = 'relu', kernel_initializer = 'glorot_normal', kernel_regularizer = regularizers.l2(0.1))(flatten)
    
  
    '''full conncet layer 2'''
    end_full_connect = Dense(full_connect_num_2, activation = 'softmax', kernel_initializer = 'glorot_normal', kernel_regularizer = regularizers.l2(0.1))(full_connect1)

    '''build model'''
    model = Model(inputs = inputs, outputs = end_full_connect)
    
    return model

# %%
'''build model obejct'''
model = resnet(input_shape = (320, 320, 3))
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 320, 320, 3)  0
# __________________________________________________________________________________________________
# bk_conv11_1 (Conv2D)            (None, 160, 160, 128 512         input_2[0][0]
# __________________________________________________________________________________________________
# bk_bn11_1 (BatchNormalization)  (None, 160, 160, 128 512         bk_conv11_1[0][0]
# __________________________________________________________________________________________________
# bk_an11_1 (Activation)          (None, 160, 160, 128 0           bk_bn11_1[0][0]
# __________________________________________________________________________________________________
# bk_conv12_1 (Conv2D)            (None, 80, 80, 128)  147584      bk_an11_1[0][0]
# __________________________________________________________________________________________________
# bk_bn12_1 (BatchNormalization)  (None, 80, 80, 128)  512         bk_conv12_1[0][0]
# __________________________________________________________________________________________________
# bk_an12_1 (Activation)          (None, 80, 80, 128)  0           bk_bn12_1[0][0]
# __________________________________________________________________________________________________
# bk_conv13_1 (Conv2D)            (None, 40, 40, 128)  16512       bk_an12_1[0][0]
# __________________________________________________________________________________________________
# bk_sk1c_1_1 (Conv2D)            (None, 40, 40, 128)  3584        input_2[0][0]
# __________________________________________________________________________________________________
# bk_bn13_1 (BatchNormalization)  (None, 40, 40, 128)  512         bk_conv13_1[0][0]
# __________________________________________________________________________________________________
# bk_sk1_1_1 (BatchNormalization) (None, 40, 40, 128)  512         bk_sk1c_1_1[0][0]
# __________________________________________________________________________________________________
# bk_an13_1 (Activation)          (None, 40, 40, 128)  0           bk_bn13_1[0][0]
# __________________________________________________________________________________________________
# bk_sk1an_1_1 (Activation)       (None, 40, 40, 128)  0           bk_sk1_1_1[0][0]
# __________________________________________________________________________________________________
# bk_add1_1_1 (Add)               (None, 40, 40, 128)  0           bk_an13_1[0][0]
#                                                                  bk_sk1an_1_1[0][0]
# __________________________________________________________________________________________________
# identify_conv1_1_1 (Conv2D)     (None, 40, 40, 256)  295168      bk_add1_1_1[0][0]
# __________________________________________________________________________________________________
# identify_bn_name1_1_1 (BatchNor (None, 40, 40, 256)  1024        identify_conv1_1_1[0][0]
# __________________________________________________________________________________________________
# identify_activation_name1_1_1 ( (None, 40, 40, 256)  0           identify_bn_name1_1_1[0][0]
# __________________________________________________________________________________________________
# identify_conv1_2_1 (Conv2D)     (None, 40, 40, 256)  590080      identify_activation_name1_1_1[0][
# __________________________________________________________________________________________________
# identify_bn_name1_2_1 (BatchNor (None, 40, 40, 256)  1024        identify_conv1_2_1[0][0]
# __________________________________________________________________________________________________
# identify_activation_name1_2_1 ( (None, 40, 40, 256)  0           identify_bn_name1_2_1[0][0]
# __________________________________________________________________________________________________
# identify_skip1_1_1 (Conv2D)     (None, 40, 40, 256)  295168      bk_add1_1_1[0][0]
# __________________________________________________________________________________________________
# identify_add1_1_1 (Add)         (None, 40, 40, 256)  0           identify_activation_name1_2_1[0][
#                                                                  identify_skip1_1_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 20, 20, 256)  0           identify_add1_1_1[0][0]
# __________________________________________________________________________________________________
# model_an_1 (Activation)         (None, 20, 20, 256)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 20, 20, 256)  0           model_an_1[0][0]
# __________________________________________________________________________________________________
# bk_conv21_1 (Conv2D)            (None, 20, 20, 512)  131584      dropout_4[0][0]
# __________________________________________________________________________________________________
# bk_bn21_1 (BatchNormalization)  (None, 20, 20, 512)  2048        bk_conv21_1[0][0]
# __________________________________________________________________________________________________
# bk_an21_1 (Activation)          (None, 20, 20, 512)  0           bk_bn21_1[0][0]
# __________________________________________________________________________________________________
# bk_conv22_1 (Conv2D)            (None, 20, 20, 512)  2359808     bk_an21_1[0][0]
# __________________________________________________________________________________________________
# bk_bn22_1 (BatchNormalization)  (None, 20, 20, 512)  2048        bk_conv22_1[0][0]
# __________________________________________________________________________________________________
# bk_an22_1 (Activation)          (None, 20, 20, 512)  0           bk_bn22_1[0][0]
# __________________________________________________________________________________________________
# bk_conv23_1 (Conv2D)            (None, 20, 20, 512)  262656      bk_an22_1[0][0]
# __________________________________________________________________________________________________
# bk_sk2c_1_1 (Conv2D)            (None, 20, 20, 512)  1180160     dropout_4[0][0]
# __________________________________________________________________________________________________
# bk_bn23_1 (BatchNormalization)  (None, 20, 20, 512)  2048        bk_conv23_1[0][0]
# __________________________________________________________________________________________________
# bk_sk2_1_1 (BatchNormalization) (None, 20, 20, 512)  2048        bk_sk2c_1_1[0][0]
# __________________________________________________________________________________________________
# bk_an23_1 (Activation)          (None, 20, 20, 512)  0           bk_bn23_1[0][0]
# __________________________________________________________________________________________________
# bk_sk2an_1_1 (Activation)       (None, 20, 20, 512)  0           bk_sk2_1_1[0][0]
# __________________________________________________________________________________________________
# bk_add2_1_1 (Add)               (None, 20, 20, 512)  0           bk_an23_1[0][0]
#                                                                  bk_sk2an_1_1[0][0]
# __________________________________________________________________________________________________
# identify_conv2_1_1 (Conv2D)     (None, 20, 20, 1024) 4719616     bk_add2_1_1[0][0]
# __________________________________________________________________________________________________
# identify_bn_name2_1_1 (BatchNor (None, 20, 20, 1024) 4096        identify_conv2_1_1[0][0]
# __________________________________________________________________________________________________
# identify_activation_name2_1_1 ( (None, 20, 20, 1024) 0           identify_bn_name2_1_1[0][0]
# __________________________________________________________________________________________________
# identify_conv2_2_1 (Conv2D)     (None, 20, 20, 1024) 9438208     identify_activation_name2_1_1[0][
# __________________________________________________________________________________________________
# identify_bn_name2_2_1 (BatchNor (None, 20, 20, 1024) 4096        identify_conv2_2_1[0][0]
# __________________________________________________________________________________________________
# identify_activation_name2_2_1 ( (None, 20, 20, 1024) 0           identify_bn_name2_2_1[0][0]
# __________________________________________________________________________________________________
# identify_skip2_1_1 (Conv2D)     (None, 20, 20, 1024) 4719616     bk_add2_1_1[0][0]
# __________________________________________________________________________________________________
# identify_add2_1_1 (Add)         (None, 20, 20, 1024) 0           identify_activation_name2_2_1[0][
#                                                                  identify_skip2_1_1[0][0]
# __________________________________________________________________________________________________
# model_an_2 (Activation)         (None, 20, 20, 1024) 0           identify_add2_1_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 20, 20, 1024) 0           model_an_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 20, 20, 1024) 0           dropout_5[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 20, 20, 1024) 0           average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 409600)       0           dropout_6[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 512)          209715712   flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 7)            3591        dense_9[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 7)            3591        dense_9[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 7)            3591        dense_9[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 7)            3591        dense_9[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 7)            3591        dense_9[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 7)            3591        dense_9[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 7)            3591        dense_9[0][0]
# ==================================================================================================
# Total params: 233,921,585
# Trainable params: 233,911,345
# Non-trainable params: 10,240
# __________________________________________________________________________________________________

# %%
plot_model(model, to_file='resnet_model1.png', show_shapes=True, show_layer_names=True, rankdir='TB')

# %%
'''test model'''
inputs = np.random.rand(5, 320, 320, 3)
model.predict(inputs)
# Out:
# [array([[8.38816259e-03, 3.14990903e-04, 4.76310233e-04, 3.95078852e-04,
#          2.57421890e-03, 3.38022801e-04, 4.40833298e-03, 9.21820523e-04,
#          3.01725157e-02, 1.15514573e-04, 1.05574218e-05, 1.60409685e-03,
#          1.43513360e-04, 2.82031740e-03, 1.07793894e-03, 5.55442972e-03,
#          2.34971871e-04, 2.73979072e-06, 4.57302289e-04, 2.47152120e-01,
#          7.86874909e-04, 5.22093265e-04, 1.06193867e-04, 2.51693081e-07,
#          5.86933311e-05, 9.13501251e-03, 4.69046086e-03, 3.70007992e-01,
#          3.96336800e-05, 5.50798359e-05, 5.91515482e-06, 5.05497883e-05,
#          2.38006294e-04, 1.01432996e-03, 5.98340668e-03, 8.68460847e-05,
#          7.82582574e-05, 1.42093413e-05, 3.87992877e-05, 2.82487861e-04,
#          1.33807759e-03, 3.72268818e-02, 1.89883955e-04, 8.63862715e-06,
#          1.03766250e-03, 1.19956920e-03, 9.97542054e-04, 5.47351510e-06,
#          7.21977813e-06, 2.48315325e-03, 2.22630543e-03, 3.86354025e-03,
#          1.56415044e-05, 9.17404774e-04, 2.17822865e-02, 6.92503672e-05,
#          6.82547269e-03, 5.11327271e-05, 1.82977878e-04, 3.66867956e-04,
#          5.33747952e-04, 4.92248219e-03, 1.32979403e-04, 8.44392402e-04,
#          2.12403864e-01, 9.53008839e-06],
#         [1.99671406e-02, 3.70510534e-04, 2.76416773e-04, 4.54327528e-04,
#          1.19632552e-03, 2.36101128e-04, 6.42408198e-03, 1.30119745e-03,
#          3.09989844e-02, 8.52905505e-05, 5.47513991e-06, 1.58399664e-04,
#          2.26423319e-04, 5.64687711e-04, 5.20456641e-04, 7.18559371e-03,
#          1.55804752e-04, 7.63734624e-06, 6.34391909e-04, 9.63024944e-02,
#          1.29887834e-04, 1.78651477e-04, 9.39821475e-05, 2.76109404e-07,
#          1.81049872e-05, 7.67612457e-03, 8.06368142e-03, 6.56223834e-01,
#          1.04400657e-04, 5.62150744e-05, 5.68692303e-06, 1.61487987e-05,
#          7.03874917e-04, 5.63565176e-04, 1.54025352e-03, 1.18543801e-04,
#          5.17421868e-05, 2.44255971e-05, 4.09214117e-05, 6.43855659e-04,
#          3.28670314e-04, 4.27646302e-02, 2.69054173e-04, 3.51884091e-06,
#          7.16122217e-04, 1.31591223e-03, 5.59896405e-04, 1.60590400e-06,
#          1.25090230e-06, 8.67450493e-04, 4.43288917e-03, 2.71463767e-03,
#          9.02519878e-06, 6.57145923e-04, 7.03613879e-03, 3.50361370e-05,
#          2.37093959e-03, 8.80559674e-05, 1.53619651e-04, 3.03189649e-04,
#          4.13386209e-04, 1.07765757e-03, 1.01249694e-04, 1.12661347e-03,
#          8.93194005e-02, 6.95056815e-06],
#         [3.66488937e-03, 3.80171783e-04, 1.66186714e-04, 5.34929219e-04,
#          3.43353930e-03, 3.67148139e-04, 4.19530738e-03, 1.06654514e-03,
#          1.59441661e-02, 8.17646360e-05, 4.11503788e-06, 5.92451019e-04,
#          2.32261402e-04, 8.03640636e-04, 5.73915255e-04, 1.55052068e-02,
#          8.29172204e-05, 7.61239244e-06, 2.24954943e-04, 1.47177279e-01,
#          5.04053547e-04, 1.15671835e-04, 2.77370651e-04, 7.12347401e-07,
#          2.71842837e-05, 1.17514441e-02, 9.86006670e-03, 4.32469964e-01,
#          1.27454099e-04, 7.55124711e-05, 9.73940678e-06, 8.03114235e-05,
#          6.18474791e-04, 1.30894419e-03, 3.17097758e-03, 1.25098144e-04,
#          1.09315544e-04, 6.40932922e-06, 4.66513047e-05, 1.70347543e-04,
#          3.81068385e-04, 4.28552553e-02, 2.43779912e-04, 1.90481751e-06,
#          7.54796434e-04, 2.17310269e-03, 3.05163005e-04, 2.12033365e-06,
#          6.27407280e-06, 1.11951178e-03, 7.17482064e-03, 2.73595680e-03,
#          1.88907434e-05, 1.05865602e-03, 1.34513555e-02, 1.04468105e-04,
#          3.81712872e-03, 6.18189151e-05, 4.71062202e-04, 2.58911430e-04,
#          5.98077313e-04, 2.55692215e-03, 5.31556580e-05, 8.62549350e-04,
#          2.63026714e-01, 1.17744376e-05],
#         [1.88806485e-02, 3.99381795e-04, 8.77630839e-04, 1.08202395e-03,
#          3.71642248e-03, 4.43430356e-04, 1.38749192e-02, 1.15573988e-03,
#          1.12595661e-02, 6.70488880e-05, 1.48089412e-05, 1.15169701e-03,
#          2.65903713e-04, 1.17066503e-03, 8.20982503e-04, 1.22956391e-02,
#          2.08570927e-04, 8.22227048e-06, 6.42523344e-04, 1.46278024e-01,
#          4.60059528e-04, 5.32387698e-04, 1.28564367e-04, 4.86035788e-07,
#          4.37505441e-05, 2.05614641e-02, 1.33467447e-02, 3.90011877e-01,
#          5.72250574e-05, 2.74555496e-04, 1.55329926e-05, 7.71349005e-05,
#          4.46444727e-04, 1.11930852e-03, 2.52390234e-03, 1.26214974e-04,
#          1.33142443e-04, 9.73102033e-06, 1.04676306e-04, 4.27787571e-04,
#          1.76503381e-03, 3.01349070e-02, 1.40872959e-04, 2.03712279e-05,
#          1.63096876e-03, 3.63017432e-03, 2.02101539e-04, 1.14365121e-05,
#          2.35732932e-06, 5.58907865e-03, 3.75616248e-03, 7.99489580e-03,
#          3.93808768e-05, 1.57247263e-03, 2.32043117e-02, 1.38084215e-04,
#          5.57109946e-03, 7.41440526e-05, 4.57202725e-04, 5.04301919e-04,
#          7.49150524e-04, 4.27640742e-03, 9.85302031e-05, 1.94795046e-03,
#          2.61447966e-01, 2.56394869e-05],
#         [1.20584229e-02, 6.52995543e-04, 9.22015461e-04, 1.06393639e-03,
#          8.56853463e-03, 4.27312538e-04, 8.11346900e-03, 8.72489763e-04,
#          1.85589064e-02, 8.24578965e-05, 4.25394364e-06, 8.31463607e-04,
#          3.90986417e-04, 1.07288093e-03, 6.81815320e-04, 4.19365382e-03,
#          3.28892405e-04, 1.34737629e-05, 2.75112165e-04, 5.90369366e-02,
#          1.61377451e-04, 2.56824831e-04, 1.93700864e-04, 4.04501918e-07,
#          4.99378402e-05, 8.02662596e-03, 7.20918784e-03, 5.16548991e-01,
#          6.91677124e-05, 1.32822344e-04, 5.71481587e-06, 3.51023336e-05,
#          7.18761759e-04, 1.26261625e-03, 3.34067107e-03, 3.13457858e-05,
#          8.02629656e-05, 8.92809749e-06, 5.30797806e-05, 1.78472153e-04,
#          2.48596398e-03, 6.01540171e-02, 2.74351856e-04, 7.84157510e-06,
#          7.27569684e-04, 5.44202933e-03, 2.63150665e-04, 2.31188096e-06,
#          2.10081180e-06, 2.33824621e-03, 2.59158621e-03, 4.62131109e-03,
#          2.13217918e-05, 1.43917440e-03, 1.81700438e-02, 5.92992619e-05,
#          2.00635334e-03, 5.09695165e-05, 1.11359623e-04, 1.00836391e-03,
#          5.99910563e-04, 5.02725970e-03, 8.31027937e-05, 5.40701207e-04,
#          2.35446945e-01, 1.07657161e-05]], dtype=float32),
#  array([[3.40877341e-05, 1.81618336e-04, 3.45824956e-05, 1.42777011e-01,
#          7.72572639e-06, 1.19325750e-05, 8.39966058e-04, 2.85418391e-05,
#          2.08943859e-02, 3.02006933e-03, 1.07715414e-05, 1.44189951e-04,
#          1.58964749e-03, 7.48091494e-04, 3.31310948e-05, 8.96442798e-04,
#          1.02457896e-04, 7.99432455e-04, 1.51367158e-05, 8.58848915e-04,
#          8.52737227e-04, 3.37188225e-03, 3.58008510e-05, 1.28767511e-04,
#          2.28590611e-03, 6.18300764e-05, 6.36472404e-01, 9.25546992e-05,
#          7.90675916e-03, 1.34470843e-04, 2.94945517e-06, 1.54510047e-03,
#          3.21258194e-05, 4.77622263e-02, 5.27148647e-03, 5.73281682e-07,
#          8.19748457e-05, 4.42982164e-05, 1.25051185e-04, 2.08204007e-03,
#          7.36994855e-03, 1.30484841e-04, 8.60285145e-05, 5.11492835e-04,
#          1.28779560e-04, 2.03390084e-02, 1.89587544e-03, 2.22784598e-04,
#          1.87349375e-04, 5.34251012e-06, 1.27155596e-04, 8.26216346e-05,
#          8.01354926e-03, 1.98304802e-02, 7.01650515e-06, 1.16123319e-05,
#          2.47234348e-05, 4.19238699e-04, 6.27774396e-04, 1.41335957e-04,
#          5.15533537e-02, 1.30949011e-05, 4.91677434e-04, 5.19191800e-03,
#          1.26574677e-03, 2.54786869e-06],
#         [2.00306167e-05, 6.80533558e-05, 8.54512109e-05, 1.15393206e-01,
#          1.71496395e-05, 3.35181103e-05, 4.76311194e-04, 1.73298649e-05,
#          5.98309338e-02, 3.21661122e-03, 1.23903410e-05, 1.70786661e-04,
#          2.89411074e-03, 6.51489827e-04, 2.14418960e-05, 1.91665033e-03,
#          2.01386472e-04, 1.18213391e-03, 6.92651702e-06, 2.36965623e-03,
#          4.95256681e-04, 6.80339616e-03, 1.81033975e-04, 1.84847740e-04,
#          2.82138982e-03, 3.10612086e-04, 4.42272067e-01, 5.17749286e-05,
#          6.04260340e-03, 8.79519735e-04, 7.05760931e-06, 1.29118946e-03,
#          4.34196118e-05, 8.30873847e-02, 3.60326841e-03, 6.26977226e-06,
#          1.66926111e-04, 8.15437961e-05, 8.31951693e-05, 6.32642163e-03,
#          8.94908700e-03, 3.38634069e-04, 6.10694624e-05, 1.76437292e-03,
#          1.43956611e-04, 1.87569689e-02, 2.13532522e-03, 7.55001267e-04,
#          3.38762824e-04, 1.37799389e-05, 2.24490126e-04, 2.61567999e-04,
#          1.65736489e-02, 3.40662152e-02, 1.67288035e-05, 6.36474260e-06,
#          4.11578949e-05, 6.04251924e-04, 1.32771232e-03, 5.49643242e-04,
#          1.61569253e-01, 9.62126887e-06, 1.09563896e-03, 4.98636020e-03,
#          2.08356115e-03, 2.01225316e-06],
#         [2.61170208e-05, 5.41872541e-05, 9.92155328e-05, 1.81984957e-02,
#          7.11340181e-06, 1.29153323e-05, 6.14925986e-04, 2.59526805e-05,
#          4.38022763e-02, 1.50207046e-03, 1.67487851e-05, 3.27508053e-04,
#          2.64253630e-03, 3.89191351e-04, 2.73330770e-05, 9.67410626e-04,
#          6.58919802e-04, 1.30591285e-03, 2.56188359e-05, 7.65166944e-04,
#          3.91363254e-04, 5.88588789e-03, 2.02633473e-05, 3.78094323e-04,
#          3.59273003e-03, 2.95540347e-04, 6.25871122e-01, 2.97708193e-05,
#          3.17750964e-03, 4.37417038e-04, 8.86316229e-06, 1.56369316e-03,
#          3.32137788e-05, 4.71238494e-02, 2.18209401e-02, 4.40957274e-06,
#          8.33277591e-05, 3.28194983e-05, 1.05999839e-04, 3.50838201e-03,
#          9.15584993e-03, 3.62776074e-04, 1.88239937e-04, 3.00806831e-04,
#          1.02287195e-04, 1.15774013e-01, 3.76939029e-03, 1.29180797e-03,
#          1.14156959e-04, 1.64656103e-05, 9.75259900e-05, 1.67109014e-04,
#          1.69781931e-02, 1.54431909e-02, 1.34822940e-05, 1.84787950e-05,
#          1.29914533e-05, 1.49447107e-04, 1.25280255e-03, 2.13901149e-04,
#          4.16785292e-02, 6.62708817e-06, 1.65282597e-03, 3.06345220e-03,
#          2.33821874e-03, 2.72272814e-06],
#         [5.33002749e-05, 1.09716704e-04, 1.63622157e-04, 1.66513994e-01,
#          7.77148034e-06, 7.45353736e-06, 5.22935356e-04, 2.12046998e-05,
#          1.84671655e-02, 8.22527683e-04, 1.53809724e-05, 1.30863395e-04,
#          6.31290860e-03, 1.04635069e-03, 9.34065465e-05, 7.07980385e-03,
#          6.72124093e-04, 7.56037305e-04, 2.61359601e-05, 1.67574384e-03,
#          7.42593489e-04, 4.44858521e-03, 2.44659095e-05, 9.24922861e-05,
#          2.52347789e-03, 1.15162533e-04, 5.75754225e-01, 2.97433235e-05,
#          1.11376783e-02, 1.54892681e-03, 3.21619018e-06, 3.79834906e-04,
#          2.13436779e-05, 3.82850543e-02, 1.32665187e-02, 2.45847377e-06,
#          6.52252565e-05, 3.47884961e-05, 1.15606752e-04, 7.27619510e-03,
#          6.17186539e-03, 6.78441720e-05, 1.21506244e-04, 6.18473860e-04,
#          9.21880273e-05, 3.41913365e-02, 2.44247867e-03, 3.54776479e-04,
#          3.01180320e-04, 2.19688627e-05, 6.76828640e-05, 1.34770176e-04,
#          3.62623185e-02, 9.64311697e-03, 2.22983363e-05, 7.64302422e-06,
#          6.23677261e-05, 3.12243646e-04, 2.45682267e-03, 3.12459306e-04,
#          3.73381861e-02, 1.60482414e-05, 1.96977495e-03, 4.11616825e-03,
#          2.52472004e-03, 3.73125499e-06],
#         [1.22142110e-05, 9.86559899e-05, 7.95684609e-05, 1.39002325e-02,
#          1.97761092e-05, 1.94710319e-05, 3.85438383e-04, 7.03165915e-06,
#          1.90443359e-02, 6.11261232e-04, 5.77828496e-06, 2.26659933e-04,
#          1.90471509e-03, 1.51136832e-03, 4.26283696e-05, 2.22356734e-03,
#          1.69969760e-04, 5.48769021e-04, 1.18233229e-05, 8.75011494e-04,
#          8.63946800e-04, 1.02614227e-03, 4.20534561e-05, 9.73535789e-05,
#          1.50566839e-03, 7.72276326e-05, 8.23282003e-01, 1.73097360e-05,
#          3.08988034e-03, 4.01241297e-04, 2.56866542e-06, 6.41490333e-04,
#          3.41549967e-05, 3.30028981e-02, 4.80834302e-03, 1.85456372e-06,
#          9.23596745e-05, 7.63847056e-05, 4.11665096e-05, 2.98014749e-03,
#          6.57716673e-03, 1.91993575e-04, 9.69138491e-05, 5.37568063e-04,
#          7.20522658e-05, 1.18286014e-02, 2.37261946e-03, 2.78413761e-04,
#          8.71318844e-05, 4.49325671e-05, 1.00922945e-04, 1.92965177e-04,
#          1.04185399e-02, 1.17074409e-02, 1.57770246e-05, 4.42493456e-06,
#          4.01689613e-05, 2.36322856e-04, 5.34432824e-04, 4.42236953e-04,
#          3.45146321e-02, 6.31187277e-06, 6.59786689e-04, 2.76324991e-03,
#          2.49210303e-03, 1.38420114e-06]], dtype=float32),
#  array([[1.07272142e-04, 1.04815420e-03, 5.51404219e-06, 5.14870117e-05,
#          2.06324717e-06, 7.56435620e-05, 6.86403888e-04, 5.14141563e-03,
#          9.05147195e-02, 3.56555138e-05, 1.27964094e-02, 8.43714084e-03,
#          1.26321018e-02, 3.08751222e-02, 1.08015782e-04, 8.25816533e-05,
#          5.37512358e-03, 2.21239007e-03, 8.09966587e-04, 9.53864364e-04,
#          8.42118334e-06, 3.72343966e-05, 3.54097690e-03, 2.89534152e-01,
#          3.54965613e-03, 2.12909276e-06, 5.84034510e-02, 1.41215976e-03,
#          1.11041181e-02, 4.65721678e-05, 8.88062132e-05, 8.12419748e-04,
#          3.29369050e-06, 6.88969856e-03, 1.22497743e-02, 3.85286898e-04,
#          9.05846628e-06, 2.24714335e-02, 1.04166847e-03, 3.15500147e-05,
#          9.41450562e-05, 8.38176311e-06, 6.29038259e-04, 3.21198459e-04,
#          7.63115459e-05, 9.54616989e-05, 3.08614387e-03, 6.12632977e-03,
#          1.08653354e-03, 3.58385470e-04, 3.71498027e-05, 9.50873437e-05,
#          5.73299185e-04, 4.50765103e-04, 4.52504959e-03, 2.71604121e-01,
#          1.19162977e-01, 9.42760453e-05, 6.52480812e-04, 6.92176764e-06,
#          3.60238264e-05, 2.49714358e-04, 5.83998999e-03, 2.45016447e-04,
#          8.64959438e-04, 1.07547276e-04],
#         [6.33638047e-05, 5.49501390e-04, 6.76380205e-06, 4.19123207e-05,
#          4.89254535e-06, 8.59951761e-05, 1.06036512e-03, 3.29203019e-03,
#          1.60278946e-01, 9.99512267e-05, 1.75459180e-02, 3.45454318e-03,
#          1.54087674e-02, 7.92699587e-03, 2.82077053e-05, 6.49370486e-05,
#          5.65708848e-03, 2.43586907e-03, 3.25698464e-04, 5.19815367e-04,
#          3.05515350e-05, 3.37103374e-05, 4.77301329e-03, 2.28996173e-01,
#          2.03026459e-03, 2.63475044e-06, 6.42820820e-02, 6.54800097e-04,
#          8.90418794e-03, 2.66992356e-05, 1.92256863e-04, 4.04201070e-04,
#          7.34037894e-06, 1.00713661e-02, 1.92717649e-02, 4.59042407e-04,
#          1.25789138e-05, 2.41598897e-02, 3.86906730e-04, 6.66033375e-05,
#          6.84743281e-05, 1.21313124e-05, 6.72600872e-04, 1.60643045e-04,
#          2.44159834e-04, 2.17019275e-04, 3.93410632e-03, 7.74818659e-03,
#          1.37302140e-03, 9.45996202e-04, 7.19819718e-06, 1.15437477e-04,
#          6.59701996e-04, 5.92618773e-04, 4.64355806e-03, 1.84179336e-01,
#          1.98232979e-01, 1.11473237e-04, 5.38210792e-04, 2.18369860e-05,
#          1.35207110e-05, 1.31504246e-04, 1.05947759e-02, 1.83956989e-04,
#          8.55435035e-04, 1.24478538e-04],
#         [1.07461121e-04, 1.11486856e-03, 1.13810429e-05, 9.04928966e-05,
#          3.99784267e-06, 2.53975795e-05, 5.83089597e-04, 4.11645882e-03,
#          1.37604699e-01, 2.96520011e-04, 6.18362203e-02, 1.72060577e-03,
#          1.75604112e-02, 5.08864373e-02, 9.92017303e-05, 1.11461923e-04,
#          1.70701612e-02, 1.74459815e-03, 2.72313104e-04, 1.29906321e-03,
#          1.61628614e-05, 5.29428435e-05, 6.36538770e-03, 1.67887777e-01,
#          2.90248147e-03, 7.11481061e-06, 1.01296559e-01, 4.90439241e-04,
#          4.70721023e-03, 1.82019157e-05, 1.43406651e-04, 1.99267568e-04,
#          6.85281884e-06, 5.74380253e-03, 3.13854516e-02, 8.37471307e-05,
#          2.78188691e-05, 1.89191848e-02, 7.05599668e-04, 4.87282705e-05,
#          9.62354316e-05, 7.22383402e-06, 7.81264156e-04, 2.54321785e-04,
#          2.12528961e-04, 1.62955112e-04, 2.27827393e-03, 1.92401465e-02,
#          9.52896196e-04, 8.15444044e-04, 3.09440511e-05, 6.69453657e-05,
#          4.89571714e-04, 6.96393254e-04, 7.54228747e-03, 1.85636088e-01,
#          1.37011632e-01, 4.02320657e-05, 2.03750227e-04, 5.68027353e-05,
#          6.00317653e-05, 1.38907359e-04, 3.78397852e-03, 1.38919873e-04,
#          1.58649520e-03, 1.52890672e-04],
#         [2.00934199e-04, 1.12064986e-03, 1.43847637e-05, 3.61442944e-05,
#          2.62225694e-06, 1.85817349e-04, 4.20149707e-04, 1.98429218e-03,
#          1.29232213e-01, 1.33750800e-04, 2.53606830e-02, 3.72440112e-03,
#          4.55559865e-02, 2.72867437e-02, 2.09158985e-04, 2.91476550e-04,
#          4.24373848e-03, 1.27660902e-03, 5.53306774e-04, 1.14079483e-03,
#          2.72301932e-05, 4.19242351e-05, 8.93004052e-03, 2.21399471e-01,
#          2.35741748e-03, 1.07239259e-06, 4.85038310e-02, 1.09958777e-03,
#          5.83622605e-03, 2.17140259e-05, 1.48650899e-04, 5.48003649e-04,
#          9.10280141e-06, 1.54108806e-02, 1.58114117e-02, 9.70521214e-05,
#          2.22815543e-05, 3.32149863e-02, 1.59582903e-03, 8.75821715e-05,
#          8.63475216e-05, 9.87820931e-06, 4.74451022e-04, 2.53693637e-04,
#          1.99580056e-04, 9.00946325e-05, 7.45312637e-03, 1.55176474e-02,
#          2.37472123e-03, 1.61517388e-03, 3.72245486e-05, 7.60346738e-05,
#          6.74171082e-04, 3.06636211e-04, 9.22987051e-03, 2.78388023e-01,
#          7.40667656e-02, 1.04678176e-04, 2.94574100e-04, 1.78354967e-05,
#          1.31112602e-05, 1.77244088e-04, 8.63428507e-03, 2.62523477e-04,
#          1.32525852e-03, 1.78914866e-04],
#         [1.39578944e-04, 1.36941136e-03, 8.01264287e-06, 4.85806668e-05,
#          1.92264724e-06, 1.72267009e-05, 9.84436134e-04, 3.98348179e-03,
#          6.66276291e-02, 4.76786190e-05, 1.22061290e-01, 5.34817437e-03,
#          2.63836831e-02, 1.32351983e-02, 1.45987462e-04, 1.10908251e-04,
#          1.97818652e-02, 9.97496187e-04, 4.24831727e-04, 6.74672367e-04,
#          4.39384385e-05, 1.61578442e-04, 5.77647472e-03, 1.29571870e-01,
#          2.80401949e-03, 4.73690943e-06, 2.53528617e-02, 3.48911126e-04,
#          1.01062935e-02, 5.75370686e-05, 1.80356103e-04, 2.58168497e-04,
#          2.63310744e-06, 3.96419968e-03, 4.12952527e-02, 1.74801447e-04,
#          6.68291323e-05, 1.20836236e-02, 3.64102336e-04, 2.03200660e-04,
#          1.87304729e-04, 8.98472899e-06, 7.71501102e-04, 1.82850607e-04,
#          3.21584492e-04, 1.66744459e-04, 1.54608814e-03, 1.00517301e-02,
#          1.59660366e-03, 9.60259407e-04, 2.15818764e-05, 9.50289323e-05,
#          1.62410608e-03, 2.62818765e-04, 1.12462882e-02, 3.31161588e-01,
#          1.32850438e-01, 1.63947727e-04, 2.62927089e-04, 1.49494990e-05,
#          2.32454368e-05, 1.90525607e-04, 9.55191720e-03, 5.31673606e-04,
#          8.93783697e-04, 9.80862387e-05]], dtype=float32),
#  array([[5.67206979e-01, 5.54422768e-05, 2.44121043e-06, 1.12141354e-03,
#          3.98624979e-05, 1.54790556e-04, 1.59921870e-03, 2.58578249e-04,
#          4.04214533e-03, 5.87841263e-03, 1.57423652e-04, 3.40993865e-05,
#          4.64588738e-05, 5.45973808e-06, 7.09947490e-04, 2.97192182e-05,
#          4.35672048e-03, 1.65867954e-02, 1.18312391e-03, 6.42167218e-03,
#          3.40125894e-06, 1.20711893e-05, 1.33688096e-04, 8.13705410e-05,
#          2.26739779e-04, 6.51990331e-06, 3.61817220e-04, 1.00839860e-03,
#          9.24111623e-03, 6.61672166e-05, 4.67812288e-06, 1.01395026e-02,
#          2.82599800e-03, 5.88711351e-04, 1.86887719e-05, 1.19790051e-03,
#          1.27190165e-03, 3.51275573e-03, 2.29135621e-03, 2.07960210e-03,
#          4.66747006e-05, 4.62557073e-04, 5.87820759e-05, 2.24932683e-05,
#          6.21827785e-03, 1.78169389e-03, 1.16205623e-03, 5.39602952e-05,
#          6.91349152e-04, 3.08612198e-01, 3.50698666e-03, 5.54709950e-05,
#          1.05900411e-03, 2.84352951e-04, 2.22099370e-05, 7.88343977e-03,
#          1.59072704e-06, 7.00984456e-05, 5.70007740e-03, 5.90730400e-04,
#          6.80288824e-04, 8.12046346e-05, 1.09680695e-04, 1.50353299e-03,
#          1.47098152e-04, 1.42311268e-02],
#         [5.44068575e-01, 3.09327261e-05, 1.73985234e-06, 2.22248549e-04,
#          6.93677384e-06, 1.44175283e-04, 5.20131318e-03, 9.84573999e-05,
#          1.20147513e-02, 1.36599573e-03, 1.87078156e-04, 2.88422070e-05,
#          1.01931160e-04, 5.99244959e-06, 2.49497010e-04, 2.38225111e-05,
#          5.36545645e-03, 3.11523350e-03, 3.28701455e-03, 6.95610885e-03,
#          5.36878997e-06, 3.35662548e-06, 8.66264018e-05, 3.74043011e-05,
#          3.90796107e-04, 8.60490036e-06, 2.71949422e-04, 5.38289431e-04,
#          7.07358308e-03, 2.22372346e-05, 7.32731542e-06, 1.05695985e-03,
#          6.18698262e-03, 2.14882835e-04, 3.36745302e-06, 8.92058713e-04,
#          8.34557868e-04, 1.53236056e-03, 4.43542842e-04, 1.18608761e-03,
#          1.41758856e-05, 1.44830847e-04, 6.84559272e-05, 1.41774526e-05,
#          1.20913051e-03, 9.11457930e-04, 1.26926112e-03, 1.13788092e-05,
#          2.67427677e-04, 3.41641158e-01, 2.50960444e-03, 2.49217683e-05,
#          4.42579435e-03, 1.41532786e-04, 2.47463704e-05, 7.51769682e-03,
#          4.78874767e-07, 5.57850508e-05, 2.25313334e-03, 1.29335490e-03,
#          6.83224876e-04, 3.25181936e-05, 8.41814326e-05, 1.11866603e-03,
#          4.19194257e-04, 3.05913389e-02],
#         [6.56395078e-01, 4.09169079e-05, 1.67314636e-06, 5.39931178e-04,
#          2.30893638e-05, 1.75945097e-04, 2.82791769e-03, 1.84156903e-04,
#          1.25243654e-02, 3.83872702e-03, 2.75808387e-04, 2.70070523e-05,
#          1.13644310e-04, 4.40843951e-06, 6.02573156e-04, 8.68865391e-06,
#          1.25750480e-02, 9.93048958e-03, 1.91631459e-03, 2.60511553e-03,
#          2.79027586e-06, 5.73481566e-06, 1.52671870e-04, 3.85097403e-04,
#          1.47241517e-04, 3.77365759e-05, 2.18914371e-04, 3.35254404e-03,
#          1.10389292e-02, 1.16764240e-04, 1.07404194e-05, 6.44328119e-03,
#          7.38167763e-03, 3.44219065e-04, 9.20973253e-06, 1.22195866e-03,
#          2.67437939e-03, 1.99286453e-03, 2.43830564e-03, 3.04490281e-03,
#          3.79906051e-05, 1.76821137e-04, 1.49316111e-04, 4.23554811e-05,
#          1.57627533e-03, 1.16992695e-03, 1.44962850e-03, 4.62293356e-05,
#          3.97546828e-04, 2.10729003e-01, 3.52844223e-03, 1.90207975e-05,
#          2.90727383e-03, 4.90444130e-04, 2.86299492e-05, 7.39298156e-03,
#          3.53847014e-07, 1.55459624e-04, 8.11658241e-03, 7.60824711e-04,
#          3.28542618e-03, 8.97120553e-05, 3.73938412e-04, 1.22171571e-03,
#          6.26676774e-04, 9.59667098e-03],
#         [6.36838675e-01, 8.57509367e-05, 3.82903863e-06, 5.05243486e-04,
#          2.85085207e-05, 4.18243464e-04, 2.14507524e-03, 2.31026745e-04,
#          5.78860566e-03, 1.19585195e-03, 1.36127361e-04, 2.08857236e-05,
#          3.67786670e-05, 1.17639502e-05, 6.20733015e-04, 1.66248774e-05,
#          5.08242892e-03, 5.14366571e-03, 2.08558096e-03, 1.22947413e-02,
#          4.91021001e-06, 5.35783875e-06, 3.50328555e-05, 1.84075121e-04,
#          2.24220959e-04, 3.16129554e-05, 8.12931103e-05, 8.75302881e-04,
#          2.05739494e-02, 1.13301292e-04, 3.85021076e-06, 5.54165803e-03,
#          4.01801197e-03, 1.56801514e-04, 8.50474680e-06, 9.31675953e-04,
#          8.58359039e-04, 2.96281488e-03, 5.67041850e-03, 1.40009401e-03,
#          6.58536956e-05, 2.74249411e-04, 7.16501163e-05, 1.34709153e-05,
#          9.59811499e-04, 8.94880388e-04, 3.17661487e-03, 2.16420849e-05,
#          4.92869760e-04, 2.30235189e-01, 4.97601647e-03, 2.41642229e-05,
#          1.55490276e-03, 2.83698493e-04, 6.33534219e-05, 1.68469474e-02,
#          3.65737691e-07, 1.74441113e-04, 5.63702965e-03, 1.06541871e-03,
#          1.84074603e-03, 1.60361436e-04, 2.10696468e-04, 9.07583628e-04,
#          3.79729026e-04, 1.32970819e-02],
#         [7.00280190e-01, 2.47139906e-05, 1.71038585e-06, 2.86686060e-04,
#          2.09933223e-05, 7.03652113e-05, 3.67338047e-03, 9.61603218e-05,
#          1.03293099e-02, 1.40763249e-03, 1.70785628e-04, 1.36031531e-05,
#          2.65345534e-05, 6.27109193e-06, 1.61203410e-04, 5.39163375e-06,
#          7.72662228e-03, 8.09897110e-03, 9.57277603e-04, 2.45976448e-03,
#          6.10890993e-06, 7.68821519e-06, 7.24021374e-05, 7.69896142e-05,
#          1.96215318e-04, 1.43028556e-05, 1.47815605e-04, 1.05360709e-03,
#          6.51965151e-03, 1.17235482e-04, 4.49806112e-06, 3.00706155e-03,
#          1.64821942e-03, 3.34083685e-04, 3.50110668e-06, 6.91640598e-04,
#          1.03446294e-03, 5.14003274e-04, 4.73608234e-04, 1.73830101e-03,
#          2.86356408e-05, 3.35665623e-04, 2.64195114e-05, 1.74527249e-05,
#          1.86083233e-03, 6.39674894e-04, 7.21582212e-04, 4.58591385e-05,
#          1.89616636e-04, 1.88078076e-01, 3.99910100e-03, 3.72459726e-05,
#          1.46759744e-03, 2.42112597e-04, 3.02038134e-05, 1.04695437e-02,
#          1.16202182e-06, 1.13051661e-04, 1.68674591e-03, 7.86286604e-04,
#          1.53292797e-03, 2.56219384e-04, 3.82776307e-05, 3.65464948e-04,
#          2.23615265e-04, 3.33280042e-02]], dtype=float32),
#  array([[1.10022083e-03, 4.96108055e-01, 2.78757125e-06, 1.30628854e-01,
#          1.33192689e-05, 5.87411516e-04, 1.08782237e-03, 3.31940362e-04,
#          2.67397518e-05, 2.40824680e-04, 2.31332189e-04, 4.84019658e-03,
#          1.16024818e-03, 4.24923579e-04, 5.56812331e-04, 2.38882229e-02,
#          9.26426321e-04, 2.10461483e-04, 3.93077824e-03, 3.36077763e-04,
#          5.96911507e-03, 6.33603008e-03, 5.79663674e-06, 8.72689299e-03,
#          1.68545503e-05, 1.22869506e-01, 1.32452129e-04, 9.56820513e-05,
#          1.63770928e-05, 7.21239427e-04, 3.45011987e-03, 1.28314951e-02,
#          6.83426159e-03, 1.09872771e-02, 3.58855980e-03, 2.22695526e-05,
#          4.01887926e-04, 1.55215130e-05, 4.15922432e-06, 3.44114937e-03,
#          5.50251342e-02, 6.55877500e-07, 3.76536482e-05, 9.00447685e-06,
#          1.62959155e-02, 1.01017693e-04, 4.33765854e-05, 3.83529137e-03,
#          1.78418513e-02, 6.18530248e-05, 2.94974801e-04, 1.69537822e-03,
#          2.87999026e-03, 4.24630096e-04, 1.23526454e-02, 4.07384272e-04,
#          3.30260862e-03, 1.69046049e-04, 7.46603764e-05, 3.96098540e-06,
#          3.60841383e-08, 8.57239047e-06, 2.64785043e-03, 2.26265896e-04,
#          1.82293021e-04, 2.89778523e-02],
#         [2.68726936e-03, 2.20183194e-01, 3.09108032e-06, 2.40274072e-01,
#          2.86703416e-05, 8.07340315e-04, 4.69828461e-04, 3.31016548e-04,
#          6.39216523e-05, 3.27568792e-04, 1.81097959e-04, 1.58116594e-03,
#          2.27391021e-03, 1.29210600e-03, 3.03895940e-04, 1.06459539e-02,
#          1.21617224e-03, 2.35319530e-04, 3.46107176e-03, 4.93797299e-04,
#          5.12524508e-03, 2.05845456e-03, 8.38021151e-06, 1.15238652e-01,
#          5.39524444e-06, 1.45946115e-01, 2.15496853e-04, 3.08850344e-04,
#          4.22212397e-05, 4.92742658e-03, 2.52651866e-03, 1.04587562e-02,
#          1.15799615e-02, 1.94729306e-02, 1.99770718e-03, 2.47267435e-05,
#          7.60939962e-04, 3.08599774e-05, 2.21188861e-06, 5.85331814e-03,
#          5.55220172e-02, 2.61360651e-06, 9.90383978e-06, 2.13563562e-05,
#          1.56740379e-02, 1.76176283e-04, 1.31487352e-04, 1.56178081e-03,
#          4.07705419e-02, 1.02392492e-04, 4.96923516e-04, 7.24569429e-04,
#          4.77997772e-03, 1.50981348e-03, 3.45755517e-02, 5.80434687e-04,
#          7.89748598e-03, 7.06727500e-04, 2.79202592e-04, 1.00139732e-05,
#          1.50878620e-07, 9.44521071e-06, 6.48238882e-03, 3.22420179e-04,
#          1.19510521e-04, 1.40884919e-02],
#         [1.69718778e-03, 2.39471883e-01, 3.46815477e-06, 2.12272450e-01,
#          2.33488081e-05, 1.11294840e-03, 1.96652240e-04, 3.14307370e-04,
#          1.45028534e-04, 4.36817034e-04, 1.32766218e-04, 3.33178067e-03,
#          6.96303963e-04, 4.93078202e-04, 4.43070923e-04, 1.14395898e-02,
#          1.76820159e-03, 2.48670316e-04, 6.80067576e-03, 2.72327015e-04,
#          5.31179085e-03, 7.91769288e-03, 9.32557214e-06, 4.31556776e-02,
#          2.30464357e-05, 1.58899307e-01, 1.48578707e-04, 2.19958471e-04,
#          2.35570842e-05, 9.07559786e-03, 4.09972435e-03, 7.23777562e-02,
#          1.13632306e-02, 1.01103224e-02, 3.96144111e-03, 8.41372730e-06,
#          4.64608544e-04, 3.47626265e-05, 1.19172428e-05, 4.66751400e-03,
#          8.13292786e-02, 1.16965032e-06, 1.38442438e-05, 1.71495722e-05,
#          2.27545463e-02, 2.14525091e-04, 9.64630817e-05, 4.09597997e-03,
#          2.50575263e-02, 1.22079509e-04, 2.22553499e-04, 1.07980892e-03,
#          4.79691895e-03, 9.02617350e-04, 1.10141020e-02, 3.08576185e-04,
#          7.15977931e-03, 4.03249520e-04, 2.85289600e-04, 8.07219658e-06,
#          1.41939339e-07, 2.54369570e-05, 5.38558839e-03, 1.47943982e-04,
#          2.75141792e-04, 2.10973788e-02],
#         [6.72324502e-04, 2.93687582e-01, 3.09852157e-06, 1.16725527e-01,
#          2.41823054e-05, 6.69203466e-04, 8.98026745e-04, 9.34593845e-05,
#          5.42245871e-05, 1.08373072e-03, 6.70304944e-05, 2.47974880e-03,
#          7.93262327e-04, 8.60569999e-04, 6.24996435e-04, 1.41890943e-02,
#          1.19636906e-03, 5.31435944e-04, 1.68548804e-03, 4.78688016e-04,
#          3.34668276e-03, 6.48275856e-03, 2.19272733e-05, 7.17275441e-02,
#          1.22420179e-05, 2.42463663e-01, 2.86959257e-04, 2.44132956e-04,
#          1.29644308e-04, 5.11672394e-03, 5.36494097e-03, 2.82249972e-02,
#          9.57025029e-03, 1.18595371e-02, 4.39179782e-03, 8.95832181e-06,
#          7.53084430e-04, 1.42780536e-05, 3.34076071e-06, 1.83382130e-03,
#          8.84172022e-02, 6.10820280e-07, 1.62390552e-05, 8.38794222e-05,
#          5.40002715e-03, 1.03905579e-04, 5.34794017e-05, 1.90273067e-03,
#          3.14624049e-02, 7.75815497e-05, 2.08151017e-04, 8.25199066e-04,
#          1.48960424e-03, 3.69363843e-04, 1.71763711e-02, 1.98640584e-04,
#          2.12953705e-03, 4.84288350e-04, 4.26907973e-05, 7.73535248e-06,
#          2.98403762e-07, 5.87570048e-06, 4.87796776e-03, 1.35879483e-04,
#          2.39035944e-04, 1.56156421e-02],
#         [2.03097146e-03, 1.90484315e-01, 6.83282997e-06, 1.04267709e-01,
#          2.57889697e-05, 6.98406482e-04, 4.82577423e-04, 3.47547233e-04,
#          2.14485714e-04, 4.40771721e-04, 1.71005042e-04, 3.95969907e-03,
#          1.26171682e-03, 9.80214099e-04, 1.08432927e-04, 6.84483498e-02,
#          3.01628769e-03, 8.74622725e-04, 3.15556466e-03, 3.57159937e-04,
#          3.44346347e-03, 7.66967610e-03, 6.91088144e-06, 1.21876914e-02,
#          3.21027910e-05, 1.77977189e-01, 5.10161219e-04, 2.08372265e-04,
#          4.82695468e-05, 6.41838973e-03, 1.28237205e-03, 9.55433697e-02,
#          1.25974324e-02, 2.72916052e-02, 7.06148800e-03, 8.34572347e-06,
#          1.67265127e-03, 8.78987994e-05, 4.91546598e-06, 3.41519387e-03,
#          1.44546717e-01, 3.09790858e-06, 4.58634604e-05, 3.08852323e-05,
#          2.53967997e-02, 1.66071521e-04, 1.74919696e-04, 1.58943539e-03,
#          2.54869610e-02, 7.19194286e-05, 7.33493129e-04, 5.04525751e-03,
#          8.87400471e-03, 3.24926747e-04, 1.09470570e-02, 4.94088104e-04,
#          1.59276854e-02, 1.65166566e-04, 1.04647494e-04, 2.03331419e-05,
#          2.88445932e-07, 5.83765541e-06, 3.33741750e-03, 3.47158813e-04,
#          2.13961568e-04, 1.71461459e-02]], dtype=float32),
#  array([[2.64838945e-07, 3.54777003e-04, 1.02782396e-04, 2.65517359e-04,
#          6.39940117e-05, 3.29880868e-06, 9.31587517e-02, 1.59623851e-05,
#          4.04492806e-04, 3.75938192e-02, 1.44974460e-04, 3.83558962e-03,
#          4.71656640e-05, 7.04028789e-05, 6.99103228e-04, 2.58800481e-03,
#          3.03001114e-04, 2.33878545e-05, 1.45592612e-05, 1.05383697e-04,
#          2.17728157e-04, 2.85844337e-02, 4.03990671e-05, 1.70904284e-04,
#          4.58197837e-06, 2.69104785e-04, 1.37475799e-05, 7.65184641e-01,
#          2.38747406e-03, 9.03865948e-05, 3.51555325e-04, 9.10547678e-05,
#          1.51057367e-03, 9.76919764e-05, 5.83660440e-04, 9.75085641e-06,
#          1.06354310e-05, 7.49421585e-03, 6.71815287e-05, 5.94157784e-04,
#          1.80431030e-04, 1.74955837e-03, 1.30501521e-05, 3.39510848e-06,
#          4.10066241e-05, 2.78473104e-04, 7.65057212e-06, 5.19040113e-05,
#          4.36185728e-05, 6.64137537e-04, 1.26677332e-06, 1.90253016e-02,
#          4.66794067e-04, 1.27163692e-03, 1.72701310e-02, 9.45802254e-04,
#          4.70410334e-04, 1.62357185e-06, 5.45390276e-03, 7.16713315e-04,
#          9.68589575e-06, 1.73889246e-04, 2.78879961e-05, 8.18411179e-04,
#          1.94323904e-04, 2.54978240e-03],
#         [1.12201042e-06, 4.63198754e-04, 1.86508507e-04, 9.75211151e-05,
#          5.04519667e-05, 5.29854969e-06, 8.52917582e-02, 2.05373617e-05,
#          3.65953805e-04, 2.12488845e-02, 4.42491109e-05, 2.36279564e-03,
#          1.44291544e-05, 8.14573868e-05, 5.16118715e-04, 1.14599394e-03,
#          3.44233558e-04, 1.17656200e-05, 4.45743062e-05, 9.64090432e-05,
#          7.67687976e-04, 2.88087614e-02, 5.01652030e-05, 2.73792713e-04,
#          3.40100155e-06, 4.05432627e-04, 3.07973169e-05, 7.93054402e-01,
#          1.44127489e-03, 3.38760183e-05, 2.05366858e-04, 5.16706677e-05,
#          9.28571215e-04, 1.39957512e-04, 2.98887258e-04, 1.50582609e-05,
#          5.36420384e-06, 6.19310839e-03, 1.47773710e-04, 1.20278518e-03,
#          9.77289237e-05, 6.49802038e-04, 7.65574987e-06, 2.79665392e-06,
#          4.36751179e-05, 5.38116321e-04, 5.11954022e-06, 6.73826798e-06,
#          3.25382243e-05, 1.21931219e-03, 4.65625135e-07, 1.58173423e-02,
#          1.02291396e-03, 1.21101527e-03, 1.97941661e-02, 1.61878683e-03,
#          5.31699741e-04, 1.86662942e-06, 7.36305024e-03, 3.53988347e-04,
#          4.66251913e-06, 9.86011510e-05, 9.38911398e-06, 8.90811381e-04,
#          2.64901348e-04, 1.96161028e-03],
#         [1.75728474e-07, 1.16726803e-03, 2.73766782e-04, 4.33893729e-04,
#          9.68016830e-05, 4.02023488e-06, 3.45392488e-02, 4.03562117e-05,
#          6.68405613e-04, 3.24229114e-02, 5.63876129e-05, 8.26815329e-03,
#          4.57847382e-05, 6.66978303e-05, 5.84801019e-04, 2.79025012e-03,
#          3.12010176e-04, 3.24283974e-05, 3.28404203e-05, 9.12188698e-05,
#          1.62274242e-04, 3.10124215e-02, 4.92766594e-05, 1.69256018e-04,
#          5.77769879e-06, 2.05141303e-04, 3.82048893e-05, 7.84338236e-01,
#          7.61274947e-03, 4.24275931e-05, 2.99117703e-04, 1.00978461e-04,
#          2.79639056e-03, 1.72708911e-04, 2.08317579e-04, 3.78405348e-05,
#          8.47907995e-06, 9.23707429e-03, 3.58946039e-04, 8.62754707e-04,
#          1.44111691e-04, 3.59442056e-04, 7.20953722e-06, 3.26106124e-06,
#          3.65120031e-05, 5.30347694e-04, 1.13058650e-05, 1.95066350e-05,
#          3.69053487e-05, 4.19372600e-03, 4.89698039e-07, 3.04163992e-02,
#          7.76309636e-04, 5.48992073e-04, 2.94405650e-02, 3.06964712e-03,
#          7.85494689e-04, 3.31861588e-06, 5.55630075e-03, 5.25367330e-04,
#          2.65539916e-06, 1.98639100e-04, 3.49570473e-05, 1.74450700e-03,
#          2.91514269e-04, 1.61670195e-03],
#         [9.50221803e-08, 4.02531790e-04, 2.49730620e-05, 2.73228798e-05,
#          5.64027687e-06, 1.23332336e-06, 1.92638263e-02, 3.34530250e-06,
#          1.03187966e-04, 5.93415741e-03, 2.61127552e-05, 2.31052958e-03,
#          1.44053283e-05, 2.31294798e-05, 6.52292147e-05, 6.28520909e-04,
#          1.20995683e-04, 2.94376241e-06, 9.91745765e-06, 1.99571205e-05,
#          5.33647981e-05, 3.94422468e-03, 1.05938207e-05, 4.37922790e-05,
#          1.16713375e-06, 4.63075776e-05, 1.82171721e-06, 9.53247666e-01,
#          1.00911316e-03, 2.12091218e-05, 3.87641521e-05, 9.88064949e-06,
#          3.09705822e-04, 2.77339968e-05, 1.85006884e-05, 3.36835524e-06,
#          1.30592537e-06, 3.00193758e-04, 9.43458599e-06, 3.27518908e-04,
#          2.34609597e-05, 1.39565265e-04, 1.37146867e-06, 3.49112838e-07,
#          5.42049884e-06, 9.18871883e-05, 1.10222356e-06, 4.80589688e-06,
#          6.52685048e-06, 2.58285640e-04, 1.21752961e-07, 4.34323912e-03,
#          4.74943110e-04, 1.51660293e-04, 4.06615995e-03, 3.56676290e-04,
#          1.17660980e-04, 3.01918249e-07, 7.95733591e-04, 9.13961994e-05,
#          9.87357112e-07, 2.44658313e-05, 2.82755104e-06, 4.15132323e-04,
#          7.33770212e-05, 1.38835778e-04],
#         [3.67163722e-07, 1.15916610e-03, 2.27053621e-04, 2.63891154e-04,
#          1.06341497e-04, 1.20465256e-05, 2.23096255e-02, 4.47187595e-05,
#          3.83375766e-04, 9.80305895e-02, 8.14518498e-05, 7.44031230e-03,
#          2.41204652e-05, 1.49509156e-04, 8.29215394e-04, 1.70458946e-03,
#          5.26829099e-04, 6.28801763e-06, 3.93385526e-05, 1.43890313e-04,
#          2.33569299e-04, 1.44313751e-02, 1.72915403e-04, 3.75492120e-04,
#          2.65065751e-06, 1.64444704e-04, 4.64962704e-06, 7.81469643e-01,
#          3.37672303e-03, 7.91037965e-05, 1.38570904e-04, 1.80946634e-04,
#          1.26751733e-03, 3.17268801e-04, 1.30152112e-04, 1.64644061e-05,
#          3.16641285e-06, 8.87479912e-03, 7.82590505e-05, 8.04408221e-04,
#          1.92977619e-04, 2.34795167e-04, 1.34846632e-05, 4.45275327e-06,
#          2.67331634e-05, 5.53430873e-04, 7.05112370e-06, 1.20549830e-05,
#          4.26829465e-05, 1.68297766e-03, 3.51939406e-07, 2.06310526e-02,
#          7.56090041e-04, 7.10118329e-04, 1.39803523e-02, 7.89888785e-04,
#          3.52690724e-04, 1.86394277e-06, 1.00027956e-02, 2.80232227e-04,
#          1.94642471e-05, 4.69046536e-05, 3.51316048e-05, 1.16115541e-03,
#          4.68521670e-04, 2.38789781e-03]], dtype=float32),
#  array([[1.16785552e-04, 1.10826504e-05, 1.28814792e-02, 6.23249861e-08,
#          5.52235942e-05, 1.51632773e-03, 3.28805414e-03, 6.49976937e-06,
#          2.37168002e-04, 1.57594495e-05, 1.86056772e-04, 7.29162130e-04,
#          8.89415620e-04, 5.88152674e-04, 2.93234666e-03, 6.26696099e-04,
#          2.10885145e-03, 9.75428993e-05, 8.92172335e-04, 4.70186169e-05,
#          1.80528755e-03, 3.46372835e-02, 1.08029584e-04, 5.53378661e-04,
#          1.53182365e-04, 2.76439278e-05, 2.60488887e-05, 5.64409653e-03,
#          2.90158973e-03, 1.84716675e-02, 5.27609512e-03, 8.81973319e-05,
#          5.74450860e-05, 8.09135090e-04, 9.57436021e-03, 3.95491137e-04,
#          1.68664043e-03, 4.63769720e-05, 7.70735517e-02, 1.77336705e-03,
#          7.30902076e-01, 1.44668782e-04, 4.45327396e-06, 1.67831672e-06,
#          2.34943131e-04, 8.53456731e-06, 3.90653219e-03, 1.40277843e-04,
#          1.82524843e-07, 7.81651877e-04, 2.79401545e-04, 3.11593425e-07,
#          6.91033027e-04, 4.47462425e-02, 7.14347698e-04, 9.61432670e-05,
#          1.53059354e-02, 4.86013305e-04, 3.76299629e-03, 8.27645243e-04,
#          6.62128208e-03, 8.98217550e-05, 7.83338328e-05, 1.76532747e-04,
#          1.65398559e-03, 1.02496679e-05],
#         [1.41992743e-04, 4.22640260e-05, 5.88292396e-03, 1.65183934e-07,
#          2.94193487e-05, 3.63132055e-03, 2.41541816e-03, 1.59323590e-05,
#          2.77659739e-04, 2.88539304e-05, 4.41286014e-04, 2.67689116e-03,
#          2.25237943e-03, 1.61389087e-03, 5.99518558e-03, 4.84536547e-04,
#          1.53267581e-03, 3.64491571e-05, 1.35808275e-03, 1.84953053e-04,
#          1.58600707e-03, 5.54908440e-02, 1.35833528e-04, 2.70960561e-04,
#          7.64610304e-04, 7.18624069e-05, 1.82493968e-04, 1.65364221e-02,
#          1.69943227e-03, 1.31087489e-02, 7.94878602e-03, 7.48620369e-05,
#          1.97525442e-04, 1.61482231e-03, 1.03381891e-02, 2.86426465e-03,
#          2.72531831e-03, 1.04622326e-04, 1.41826972e-01, 2.70382478e-03,
#          6.06333375e-01, 1.84179095e-04, 4.38455436e-06, 3.29304021e-06,
#          4.56296082e-04, 4.04433122e-05, 7.88453314e-03, 2.45378644e-04,
#          2.14807329e-07, 1.02155539e-03, 1.60070392e-03, 4.13627140e-06,
#          1.51832821e-04, 5.45118526e-02, 4.09739354e-04, 7.06726220e-04,
#          1.66256428e-02, 1.55935506e-03, 6.09819777e-03, 3.69131507e-04,
#          9.92005784e-03, 3.18585517e-04, 4.02063415e-05, 1.10683660e-03,
#          1.08354923e-03, 3.09192801e-05],
#         [7.19733944e-05, 1.68545575e-05, 2.44158460e-03, 5.54906556e-08,
#          4.02523510e-05, 2.39367737e-03, 4.33406327e-03, 8.68751613e-06,
#          1.21674741e-04, 1.02412878e-05, 3.42059822e-04, 1.75696949e-03,
#          4.09140252e-04, 5.61152468e-04, 4.42882115e-03, 6.49430964e-04,
#          9.15368611e-04, 3.28868337e-05, 6.36476092e-04, 4.79589726e-05,
#          4.78324294e-03, 3.58599573e-02, 1.79586947e-04, 2.66542076e-04,
#          2.01425544e-04, 1.05033578e-05, 3.81952668e-05, 8.57878663e-03,
#          1.33214367e-03, 2.60836855e-02, 4.19976097e-03, 1.21727659e-04,
#          4.64896402e-05, 3.42550484e-04, 1.17196506e-02, 9.02540749e-04,
#          7.67267542e-04, 4.98230984e-05, 8.93991888e-02, 2.25764862e-03,
#          6.86702967e-01, 1.79527866e-04, 1.29201881e-05, 1.28496856e-06,
#          1.86779507e-04, 1.19969272e-05, 1.68324560e-02, 3.90807603e-04,
#          2.32994267e-07, 9.88819171e-04, 1.14034733e-03, 2.14882289e-06,
#          1.48766208e-03, 1.83357038e-02, 5.28702163e-04, 2.49395758e-04,
#          4.94842641e-02, 1.15669123e-03, 6.02877047e-03, 1.43379642e-04,
#          8.41264892e-03, 6.73582690e-05, 6.07757538e-05, 3.25170084e-04,
#          8.95472709e-04, 1.35727296e-05],
#         [3.94541188e-04, 3.34052238e-05, 5.52679319e-03, 1.06781414e-07,
#          7.69195176e-05, 1.49772456e-03, 6.08520629e-03, 2.13465610e-05,
#          3.03904468e-04, 8.89523653e-06, 4.50209744e-04, 2.26714672e-03,
#          7.85952492e-04, 9.83209698e-04, 2.64433422e-03, 1.46658707e-03,
#          9.11234505e-03, 4.87177313e-05, 1.61100121e-03, 6.60145452e-05,
#          5.89827634e-03, 8.02751780e-02, 2.67801282e-04, 9.12266551e-04,
#          1.26362313e-03, 6.26183100e-05, 2.56971573e-04, 2.36884635e-02,
#          1.05178938e-03, 3.31271403e-02, 8.19792040e-03, 1.72939544e-04,
#          1.77309281e-04, 6.34348893e-04, 1.67977680e-02, 2.28004367e-03,
#          5.30459033e-03, 9.23276239e-05, 2.17834532e-01, 5.42942714e-03,
#          4.55250055e-01, 5.08084369e-04, 1.31742700e-05, 4.08676760e-06,
#          3.67301749e-04, 2.68398544e-05, 2.77389996e-02, 2.41799557e-04,
#          2.14854012e-07, 4.20552678e-03, 6.88804779e-04, 2.63532638e-06,
#          9.42180166e-04, 1.97645873e-02, 9.26953915e-04, 1.16213690e-04,
#          3.59797105e-02, 9.41944774e-04, 7.89032411e-03, 5.60933200e-04,
#          2.93674576e-03, 1.18614465e-04, 1.00484979e-03, 8.96480691e-04,
#          1.73384044e-03, 2.93844314e-05],
#         [2.07391320e-04, 2.44102557e-05, 8.09332263e-03, 1.55654547e-07,
#          7.08505177e-05, 1.74677558e-03, 4.44011018e-03, 2.01079947e-05,
#          3.69385671e-04, 4.89149534e-05, 2.65843060e-04, 7.73099426e-04,
#          4.18545445e-03, 3.43303313e-03, 7.01342290e-03, 9.50403570e-04,
#          2.89263134e-03, 2.24486648e-04, 2.61321990e-03, 8.19102570e-05,
#          8.20883084e-03, 1.51876166e-01, 4.65272286e-04, 4.58468421e-04,
#          5.94956102e-04, 6.57005367e-05, 2.18861271e-04, 1.98933389e-02,
#          6.88607339e-03, 3.84439044e-02, 6.38839509e-03, 2.30892139e-04,
#          7.53677159e-04, 8.71972530e-04, 3.04546431e-02, 3.51538206e-03,
#          5.07620350e-03, 1.05773244e-04, 1.25564843e-01, 2.44723773e-03,
#          4.30120498e-01, 4.53588844e-04, 1.65084602e-05, 3.63211029e-06,
#          2.87840987e-04, 3.28684619e-05, 3.36107910e-02, 2.86900555e-04,
#          3.52954743e-07, 1.20395399e-03, 2.91030598e-03, 1.12436919e-05,
#          1.02239230e-03, 2.69013159e-02, 6.64196152e-04, 2.47615681e-04,
#          4.01284918e-02, 7.32038170e-04, 5.62689966e-03, 6.55011856e-04,
#          6.68481085e-03, 1.30591972e-04, 1.10360823e-04, 1.24457048e-03,
#          6.91709993e-03, 2.06829973e-05]], dtype=float32)]

# %%
'''compile model'''
model.compile(loss = 'mean_squared_error', optimizer = 'adadelta', metrics = ['accuracy'])

# %%
'''train model'''
model.fit(X_train, Y_train, batch_size = 8, epochs = 5)
# Out:
# Epoch 1/5
# 1225/1225 [==============================] - 17361s 14s/step - loss: 448879.5567 - acc: 0.0563
# Epoch 2/5
# 1225/1225 [==============================] - 17694s 14s/step - loss: 1059.4438 - acc: 0.0498
# Epoch 3/5
# 1225/1225 [==============================] - 17632s 14s/step - loss: 1057.5573 - acc: 0.0531
# Epoch 4/5
# 1225/1225 [==============================] - 17524s 14s/step - loss: 1052.4273 - acc: 0.0637
# Epoch 5/5
# 1225/1225 [==============================] - 17273s 14s/step - loss: 1132.2507 - acc: 0.0506

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 320, 320)     0
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 320, 320, 1)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 157, 157, 64) 3200        reshape_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 157, 157, 64) 36928       conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 157, 157, 64) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 157, 157, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 157, 157, 64) 36928       conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 157, 157, 64) 36928       dropout_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 157, 157, 64) 0           conv2d_4[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 157, 157, 64) 0           add_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 157, 157, 64) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 157, 157, 64) 36928       dropout_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 157, 157, 64) 0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 157, 157, 64) 0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 157, 157, 64) 36928       dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 157, 157, 64) 36928       dropout_3[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 157, 157, 64) 0           conv2d_7[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 157, 157, 64) 0           add_2[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 157, 157, 64) 0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 157, 157, 64) 36928       dropout_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 157, 157, 64) 0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 157, 157, 64) 0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 157, 157, 64) 36928       dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 157, 157, 64) 36928       dropout_5[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 157, 157, 64) 0           conv2d_10[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 157, 157, 64) 0           add_3[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 157, 157, 64) 0           activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 157, 157, 64) 36928       dropout_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 157, 157, 64) 0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 157, 157, 64) 0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 157, 157, 64) 36928       dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 157, 157, 64) 36928       dropout_7[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 157, 157, 64) 0           conv2d_13[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 157, 157, 64) 0           add_4[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 157, 157, 64) 0           activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 157, 157, 64) 36928       dropout_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 157, 157, 64) 0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 157, 157, 64) 0           activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 157, 157, 64) 36928       dropout_8[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 157, 157, 64) 36928       dropout_9[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 157, 157, 64) 0           conv2d_16[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 157, 157, 64) 0           add_5[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 157, 157, 64) 0           activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 157, 157, 64) 4160        dropout_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 157, 157, 64) 0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 157, 157, 64) 36928       activation_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 157, 157, 64) 0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 157, 157, 256 147712      activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 157, 157, 256 16640       dropout_10[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 157, 157, 256 0           conv2d_20[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 157, 157, 256 0           add_6[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 157, 157, 256 0           activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 157, 157, 64) 16448       dropout_11[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 157, 157, 64) 0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 157, 157, 64) 36928       activation_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 157, 157, 64) 0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 157, 157, 256 147712      activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 157, 157, 256 65792       dropout_11[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 157, 157, 256 0           conv2d_24[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 157, 157, 256 0           add_7[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 157, 157, 256 0           activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 157, 157, 64) 16448       dropout_12[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 157, 157, 64) 0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 157, 157, 64) 36928       activation_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 157, 157, 64) 0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 157, 157, 256 147712      activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 157, 157, 256 65792       dropout_12[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 157, 157, 256 0           conv2d_28[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 157, 157, 256 0           add_8[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 157, 157, 256 0           activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 157, 157, 64) 16448       dropout_13[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 157, 157, 64) 0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 157, 157, 64) 36928       activation_20[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 157, 157, 64) 0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 157, 157, 256 147712      activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 157, 157, 256 65792       dropout_13[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 157, 157, 256 0           conv2d_32[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 157, 157, 256 0           add_9[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 157, 157, 256 0           activation_22[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 157, 157, 64) 16448       dropout_14[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 157, 157, 64) 0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 157, 157, 64) 36928       activation_23[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 157, 157, 64) 0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 157, 157, 256 147712      activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 157, 157, 256 65792       dropout_14[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 157, 157, 256 0           conv2d_36[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 157, 157, 256 0           add_10[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 157, 157, 256 0           activation_25[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 156, 156, 256 0           dropout_15[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 156, 156, 256 0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 6230016)      0           activation_26[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 7)            43610119    flatten_1[0][0]
# ==================================================================================================
# Total params: 45,440,199
# Trainable params: 45,440,199
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
config_file = 'config_file.pickle'

# %%
config = model.get_config()
with open(config_file, 'wb') as f:
    pickle.dump({'config': config}, f)

# %%
weights_resnet_1 = 'weights_resnet_1.h5'
model.save_weights(weights_resnet_1)

# %%
# X = X_train[10]
# y = model.predict(X.reshape((1, 320, 320)))
plt.imshow(X_train[10])
print(utils.getLabel(root, filename, Y_train[10]))
# Out:
# 云D86999
