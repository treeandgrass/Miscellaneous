# %%
from ImageUtils import ImageUtils
import os
import numpy as np
import matplotlib.pyplot as plt
import pickle
from pandas import read_excel

# %%
sourceFolder = 'D:/jupyter/car-management/recognitionalgorithm/dataset/rimages'
targetFolder = 'D:/jupyter/car-management/recognitionalgorithm/dataset/rimagesResize320'
root = 'D:/jupyter/car-management/recognitionalgorithm/dataset'
Xfilename = 'licenseplateL.npy'
Yfilename = 'label.npy'
filename = '字典.xlsx'

# %%
imageUtils = ImageUtils()

# %%
imageUtils.resizeAndSaveImage(sourceFolder, targetFolder)

# %%
X = imageUtils.readXData(targetFolder, shape = (320, 320, 3))
Y = imageUtils.readYData(root, targetFolder, filename)
imageUtils.save(root, Xfilename, Yfilename, X, Y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-8049f7daa362> in <module>()
# ----> 1 X = imageUtils.readXData(targetFolder)
#       2 Y = imageUtils.readYData(root, targetFolder, filename)
#       3 imageUtils.save(root, Xfilename, Yfilename, X, Y)
#
# D:\jupyter\car-management\recognitionalgorithm\ImageUtils.py in readXData(self, folder, shape)
#     121             im = self.readImage(path)
#     122 #             Xdata[i] = self.imagenorm(im)
# --> 123             Xdata[i] = im
#     124         return Xdata
#     125
#
# ValueError: could not broadcast input array from shape (320,320,3) into shape (320,320)

# %%
imageUtils = ImageUtils()
X, Y = imageUtils.load(root, Xfilename, Yfilename)
print(X.shape, Y.shape)
# Out:
# (1222, 320, 320) (1222, 7)

# %%
print(imageUtils.getLabel(root, filename, Y[14]))
plt.imshow(X[14])
# Out:
# 云DSB110
